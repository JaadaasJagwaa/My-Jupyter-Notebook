# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# ## Jaadaas Jagwaa

# %% [markdown]
# QA Software Tester

# %% [markdown]
# ###### I am interested in Data Science to gain more competencies in anaylzing data for the purposes of software testing to support my current role. I'd like to build my computer science portofolio to expand my career growth, and data science seems like a good fit, plus it would be good skills to bring back to my Indigenous communities.

# %% [markdown]
# ### The Python code in the cell below is to subtract 7 from 77

# %%
77-7
# Out:
# 70

# %% [markdown]
# My | Jupyter | Notebook
# --- | --- | ---
# *Still* | `renders` | **pretty**
# 1 | 2 | 3
